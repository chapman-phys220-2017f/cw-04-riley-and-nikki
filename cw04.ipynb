# %%
import cw04
import pandas as pd

# %% [markdown]
# # Classwork 04
#
# Riley Kendall and Nikki Schwartz
#
# 9/21/17
#
# ## Description
#
# The following code benchmarks and plots functions approximated both as python lists and as numpy arrays.

# %% [markdown]
# ### Module Documentation
#
# For illustration, we show how the python help system naturally uses the docstrings from the code.

# %%
help(cw04)
# Out:
# Help on module cw04:
#
# NAME
#     cw04
#
# DESCRIPTION
#     Classwork 04
#     This classwork introduces numpy arrays and compares their performance to
#     python lists.
#
# FUNCTIONS
#     gen_gaussian_array(a, b, n=1000)
#         gen_gaussian_array(a, b, n=1000)
#         Generate a discrete approximation of a Gaussian function, including its
#         domain and range, stored as a pair of numpy arrays.
#
#         Args:
#             a (float) : Lower bound of domain
#             b (float) : Upper bound of domain
#             n (int, optional) : Number of points in domain, defaults to 1000.
#
#         Returns:
#             (x, g) : Pair of numpy arrays of float64
#                 x  : [a, ..., b] Array of n equally spaced float64 between a and b
#                 g  : [g(a), ..., g(b)] Array of Gaussian values matched to x
#
#     gen_gaussian_list(a, b, n=1000)
#         gen_gaussian_list(a, b, n=1000)
#         Generate a discrete approximation of a Gaussian function, including its
#         domain and range, stored as a pair of vanilla python lists.
#
#         Args:
#             a (float) : Lower bound of domain
#             b (float) : Upper bound of domain
#             n (int, optional) : Number of points in domain, defaults to 1000.
#
#         Returns:
#             (x, g) : Pair of lists of floats
#                 x  : [a, ..., b] List of n equally spaced floats between a and b
#                 g  : [g(a), ..., g(b)] List of Gaussian values matched to x
#
#     main(a, b, n=1000)
#         main(a, b, n=1000)
#         Main function for command line operation. Prints result of Gaussian to screen.
#
#         Args:
#             a (float) : Lower bound of domain
#             b (float) : Upper bound of domain
#             n (int, optional) : Number of points in domain, defaults to 1000.
#
#         Returns:
#             None
#
#         Effects:
#             Prints Gaussian to screen.
#
#     sinc_array(a, b, n=10000)
#         sinc_array(a, b, n=10000)
#         Generate a discrete approximation of a Sinc function, including its
#         domain and range, stored as a pair of numpy arrays.
#
#         Args:
#             a (float) : Lower bound of domain
#             b (float) : Upper bound of domain
#             n (int, optional) : Number of points in domain, defaults to 10000.
#
#         Returns:
#             (x, g) : Pair of numpy arrays of float64
#                 x  : [a, ..., b] Array of n equally spaced float64 between a and b
#                 g  : [g(a), ..., g(b)] Array of Gaussian values matched to x
#
#     sinc_list(a, b, n=10000)
#         sinc_list(a, b, n=10000)
#         Generate a discrete approximation of a Sinc function, including its
#         domain and range, stored as a pair of vanilla python lists.
#
#         Args:
#             a (float) : Lower bound of domain
#             b (float) : Upper bound of domain
#             n (int, optional) : Number of points in domain, defaults to 10000.
#
#         Returns:
#             (x, g) : Pair of lists of floats
#                 x  : [a, ..., b] List of n equally spaced floats between a and b
#                 g  : [g(a), ..., g(b)] List of Gaussian values matched to x
#
# FILE
#     /home/user/04-Work/cw-04-riley-and-nikki/cw04.py

# %%
help(cw04.gen_gaussian_list)
# Out:
# Help on function gen_gaussian_list in module cw04:
#
# gen_gaussian_list(a, b, n=1000)
#     gen_gaussian_list(a, b, n=1000)
#     Generate a discrete approximation of a Gaussian function, including its
#     domain and range, stored as a pair of vanilla python lists.
#
#     Args:
#         a (float) : Lower bound of domain
#         b (float) : Upper bound of domain
#         n (int, optional) : Number of points in domain, defaults to 1000.
#
#     Returns:
#         (x, g) : Pair of lists of floats
#             x  : [a, ..., b] List of n equally spaced floats between a and b
#             g  : [g(a), ..., g(b)] List of Gaussian values matched to x

# %%
cw04.gen_gaussian_array
# Out:
# <function cw04.gen_gaussian_array>

# %% [markdown]
# ### Python Lists
#
# Benchmark and plot the reference list implementation.

# %% [markdown]
# #### Gaussian Function

# %%
# %time x, g = cw04.gen_gaussian_list(-10,10,10000)
# Out:
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 9.7 ms

# %%
gauss = pd.DataFrame({"x":x,"g(x)":g})

# %%
gauss
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>g(x)</th>
#       <th>x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.694599e-23</td>
#       <td>-10.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.850040e-23</td>
#       <td>-9.998000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>8.008589e-23</td>
#       <td>-9.996000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.170308e-23</td>
#       <td>-9.993999</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8.335259e-23</td>
#       <td>-9.991999</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>8.503506e-23</td>
#       <td>-9.989999</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8.675115e-23</td>
#       <td>-9.987999</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8.850152e-23</td>
#       <td>-9.985999</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9.028684e-23</td>
#       <td>-9.983998</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9.210780e-23</td>
#       <td>-9.981998</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>9.396512e-23</td>
#       <td>-9.979998</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>9.585951e-23</td>
#       <td>-9.977998</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>9.779169e-23</td>
#       <td>-9.975998</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>9.976243e-23</td>
#       <td>-9.973997</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1.017725e-22</td>
#       <td>-9.971997</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1.038226e-22</td>
#       <td>-9.969997</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1.059136e-22</td>
#       <td>-9.967997</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1.080463e-22</td>
#       <td>-9.965997</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1.102215e-22</td>
#       <td>-9.963996</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1.124400e-22</td>
#       <td>-9.961996</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1.147027e-22</td>
#       <td>-9.959996</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1.170105e-22</td>
#       <td>-9.957996</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1.193642e-22</td>
#       <td>-9.955996</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1.217648e-22</td>
#       <td>-9.953995</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1.242132e-22</td>
#       <td>-9.951995</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1.267103e-22</td>
#       <td>-9.949995</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1.292571e-22</td>
#       <td>-9.947995</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1.318545e-22</td>
#       <td>-9.945995</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1.345037e-22</td>
#       <td>-9.943994</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1.372054e-22</td>
#       <td>-9.941994</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9970</th>
#       <td>1.372054e-22</td>
#       <td>9.941994</td>
#     </tr>
#     <tr>
#       <th>9971</th>
#       <td>1.345037e-22</td>
#       <td>9.943994</td>
#     </tr>
#     <tr>
#       <th>9972</th>
#       <td>1.318545e-22</td>
#       <td>9.945995</td>
#     </tr>
#     <tr>
#       <th>9973</th>
#       <td>1.292571e-22</td>
#       <td>9.947995</td>
#     </tr>
#     <tr>
#       <th>9974</th>
#       <td>1.267103e-22</td>
#       <td>9.949995</td>
#     </tr>
#     <tr>
#       <th>9975</th>
#       <td>1.242132e-22</td>
#       <td>9.951995</td>
#     </tr>
#     <tr>
#       <th>9976</th>
#       <td>1.217648e-22</td>
#       <td>9.953995</td>
#     </tr>
#     <tr>
#       <th>9977</th>
#       <td>1.193642e-22</td>
#       <td>9.955996</td>
#     </tr>
#     <tr>
#       <th>9978</th>
#       <td>1.170105e-22</td>
#       <td>9.957996</td>
#     </tr>
#     <tr>
#       <th>9979</th>
#       <td>1.147027e-22</td>
#       <td>9.959996</td>
#     </tr>
#     <tr>
#       <th>9980</th>
#       <td>1.124400e-22</td>
#       <td>9.961996</td>
#     </tr>
#     <tr>
#       <th>9981</th>
#       <td>1.102215e-22</td>
#       <td>9.963996</td>
#     </tr>
#     <tr>
#       <th>9982</th>
#       <td>1.080463e-22</td>
#       <td>9.965997</td>
#     </tr>
#     <tr>
#       <th>9983</th>
#       <td>1.059136e-22</td>
#       <td>9.967997</td>
#     </tr>
#     <tr>
#       <th>9984</th>
#       <td>1.038226e-22</td>
#       <td>9.969997</td>
#     </tr>
#     <tr>
#       <th>9985</th>
#       <td>1.017725e-22</td>
#       <td>9.971997</td>
#     </tr>
#     <tr>
#       <th>9986</th>
#       <td>9.976243e-23</td>
#       <td>9.973997</td>
#     </tr>
#     <tr>
#       <th>9987</th>
#       <td>9.779169e-23</td>
#       <td>9.975998</td>
#     </tr>
#     <tr>
#       <th>9988</th>
#       <td>9.585951e-23</td>
#       <td>9.977998</td>
#     </tr>
#     <tr>
#       <th>9989</th>
#       <td>9.396512e-23</td>
#       <td>9.979998</td>
#     </tr>
#     <tr>
#       <th>9990</th>
#       <td>9.210780e-23</td>
#       <td>9.981998</td>
#     </tr>
#     <tr>
#       <th>9991</th>
#       <td>9.028684e-23</td>
#       <td>9.983998</td>
#     </tr>
#     <tr>
#       <th>9992</th>
#       <td>8.850152e-23</td>
#       <td>9.985999</td>
#     </tr>
#     <tr>
#       <th>9993</th>
#       <td>8.675115e-23</td>
#       <td>9.987999</td>
#     </tr>
#     <tr>
#       <th>9994</th>
#       <td>8.503506e-23</td>
#       <td>9.989999</td>
#     </tr>
#     <tr>
#       <th>9995</th>
#       <td>8.335259e-23</td>
#       <td>9.991999</td>
#     </tr>
#     <tr>
#       <th>9996</th>
#       <td>8.170308e-23</td>
#       <td>9.993999</td>
#     </tr>
#     <tr>
#       <th>9997</th>
#       <td>8.008589e-23</td>
#       <td>9.996000</td>
#     </tr>
#     <tr>
#       <th>9998</th>
#       <td>7.850040e-23</td>
#       <td>9.998000</td>
#     </tr>
#     <tr>
#       <th>9999</th>
#       <td>7.694599e-23</td>
#       <td>10.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p>10000 rows × 2 columns</p>
# </div>

# %%
gauss.plot(x="x",y="g(x)")

# %% [markdown]
# #### Sinc Function

# %%
# %time x, g = cw04.sinc_list(-10,10,10000)
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 5.32 ms

# %%
sinc = pd.DataFrame({"x":x,"g(x)":g})

# %%
sinc
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>g(x)</th>
#       <th>x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.054402</td>
#       <td>-10.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.054245</td>
#       <td>-9.998000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.054088</td>
#       <td>-9.996000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.053930</td>
#       <td>-9.993999</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.053772</td>
#       <td>-9.991999</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-0.053614</td>
#       <td>-9.989999</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.053455</td>
#       <td>-9.987999</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.053297</td>
#       <td>-9.985999</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.053138</td>
#       <td>-9.983998</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.052978</td>
#       <td>-9.981998</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.052819</td>
#       <td>-9.979998</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.052659</td>
#       <td>-9.977998</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>-0.052499</td>
#       <td>-9.975998</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-0.052338</td>
#       <td>-9.973997</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>-0.052178</td>
#       <td>-9.971997</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>-0.052017</td>
#       <td>-9.969997</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>-0.051855</td>
#       <td>-9.967997</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>-0.051694</td>
#       <td>-9.965997</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>-0.051532</td>
#       <td>-9.963996</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>-0.051370</td>
#       <td>-9.961996</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>-0.051208</td>
#       <td>-9.959996</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>-0.051045</td>
#       <td>-9.957996</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>-0.050882</td>
#       <td>-9.955996</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>-0.050719</td>
#       <td>-9.953995</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>

#       <td>10.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p>10000 rows × 2 columns</p>
# </div>

# %%
sinc.plot(x="x",y="g(x)")

# %% [markdown]
# ### Numpy Arrays

# %% [markdown]
# #### Gaussian Function

# %%
# %time x, g = cw04.gen_gaussian_array(-10, 10, 100000)
# Out:
# CPU times: user 96 ms, sys: 0 ns, total: 96 ms
# Wall time: 101 ms

# %%
gauss = pd.DataFrame({"x":x,"g(x)":g})

# %%
gauss
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>g(x)</th>
#       <th>x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.054402</td>
#       <td>-10.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.054245</td>
#       <td>-9.998000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.054088</td>
#       <td>-9.996000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.053930</td>
#       <td>-9.993999</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.053772</td>
#       <td>-9.991999</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-0.053614</td>
#       <td>-9.989999</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>-0.053455</td>
#       <td>-9.987999</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-0.053297</td>
#       <td>-9.985999</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.053138</td>
#       <td>-9.983998</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.052978</td>
#       <td>-9.981998</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.052819</td>
#       <td>-9.979998</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.052659</td>
#       <td>-9.977998</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>-0.052499</td>
#       <td>-9.975998</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-0.052338</td>
#       <td>-9.973997</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>-0.052178</td>
#       <td>-9.971997</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>-0.052017</td>
#       <td>-9.969997</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>-0.051855</td>
#       <td>-9.967997</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>-0.051694</td>
#       <td>-9.965997</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>-0.051532</td>
#       <td>-9.963996</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>-0.051370</td>
#       <td>-9.961996</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>-0.051208</td>
#       <td>-9.959996</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>-0.051045</td>
#       <td>-9.957996</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>-0.050882</td>
#       <td>-9.955996</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>-0.050719</td>
#       <td>-9.953995</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>-0.050556</td>
#       <td>-9.951995</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>-0.050392</td>
#       <td>-9.949995</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>-0.050228</td>
#       <td>-9.947995</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>-0.050064</td>
#       <td>-9.945995</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>-0.049899</td>
#       <td>-9.943994</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>-0.049735</td>
#       <td>-9.941994</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9970</th>
#       <td>-0.049735</td>
#       <td>9.941994</td>
#     </tr>
#     <tr>
#       <th>9971</th>
#       <td>-0.049899</td>
#       <td>9.943994</td>
#     </tr>
#     <tr>
#       <th>9972</th>
#       <td>-0.050064</td>
#       <td>9.945995</td>
#     </tr>
#     <tr>
#       <th>9973</th>
#       <td>-0.050228</td>
#       <td>9.947995</td>
#     </tr>
#     <tr>
#       <th>9974</th>
#       <td>-0.050392</td>
#       <td>9.949995</td>
#     </tr>
#     <tr>
#       <th>9975</th>
#       <td>-0.050556</td>
#       <td>9.951995</td>
#     </tr>
#     <tr>
#       <th>9976</th>
#       <td>-0.050719</td>
#       <td>9.953995</td>
#     </tr>
#     <tr>
#       <th>9977</th>
#       <td>-0.050882</td>
#       <td>9.955996</td>
#     </tr>
#     <tr>
#       <th>9978</th>
#       <td>-0.051045</td>
#       <td>9.957996</td>
#     </tr>
#     <tr>
#       <th>9979</th>
#       <td>-0.051208</td>
#       <td>9.959996</td>
#     </tr>
#     <tr>
#       <th>9980</th>
#       <td>-0.051370</td>
#       <td>9.961996</td>
#     </tr>
#     <tr>
#       <th>9981</th>
#       <td>-0.051532</td>
#       <td>9.963996</td>
#     </tr>
#     <tr>
#       <th>9982</th>
#       <td>-0.051694</td>
#       <td>9.965997</td>
#     </tr>
#     <tr>
#       <th>9983</th>
#       <td>-0.051855</td>
#       <td>9.967997</td>
#     </tr>
td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9970</th>
#       <td>-0.049735</td>
#       <td>9.941994</td>
#     </tr>
#     <tr>
#       <th>9971</th>
#       <td>-0.049899</td>
#       <td>9.943994</td>
#     </tr>
#     <tr>
#       <th>9972</th>
#       <td>-0.050064</td>
#       <td>9.945995</td>
#     </tr>
#     <tr>
#       <th>9973</th>
#       <td>-0.050228</td>
#       <td>9.947995</td>
#     </tr>
#     <tr>
#       <th>9974</th>
#       <td>-0.050392</td>
#       <td>9.949995</td>
#     </tr>
#     <tr>
#       <th>9975</th>
#       <td>-0.050556</td>
#       <td>9.951995</td>
#     </tr>
#     <tr>
#       <th>9976</th>
#       <td>-0.050719</td>
#       <td>9.953995</td>
#     </tr>
#     <tr>
#       <th>9977</th>
#       <td>-0.050882</td>
#       <td>9.955996</td>
#     </tr>
#     <tr>
#       <th>9978</th>
#       <td>-0.051045</td>
#       <td>9.957996</td>
#     </tr>
#     <tr>
#       <th>9979</th>
#       <td>-0.051208</td>
#       <td>9.959996</td>
#     </tr>
#     <tr>
#       <th>9980</th>
#       <td>-0.051370</td>
#       <td>9.961996</td>
#     </tr>
#     <tr>
#       <th>9981</th>
#       <td>-0.051532</td>
#       <td>9.963996</td>
#     </tr>
#     <tr>
#       <th>9982</th>
#       <td>-0.051694</td>
#       <td>9.965997</td>
#     </tr>
#     <tr>
#       <th>9983</th>
#       <td>-0.051855</td>
#       <td>9.967997</td>
#     </tr>
#     <tr>
#       <th>9984</th>
#       <td>-0.052017</td>
#       <td>9.969997</td>
#     </tr>
#     <tr>
#       <th>9985</th>
#       <td>-0.052178</td>
#       <td>9.971997</td>
#     </tr>
#     <tr>
#       <th>9986</th>
#       <td>-0.052338</td>
#       <td>9.973997</td>
#     </tr>
#     <tr>
#       <th>9987</th>
#       <td>-0.052499</td>
#       <td>9.975998</td>
#     </tr>
#     <tr>
#       <th>9988</th>
#       <td>-0.052659</td>
#       <td>9.977998</td>
#     </tr>
#     <tr>
#       <th>9989</th>
#       <td>-0.052819</td>
#       <td>9.979998</td>
#     </tr>
#     <tr>
#       <th>9990</th>
#       <td>-0.052978</td>
#       <td>9.981998</td>
#     </tr>
#     <tr>
#       <th>9991</th>
#       <td>-0.053138</td>
#       <td>9.983998</td>
#     </tr>
#     <tr>
#       <th>9992</th>
#       <td>-0.053297</td>
#       <td>9.985999</td>
#     </tr>
#     <tr>
#       <th>9993</th>
#       <td>-0.053455</td>
#       <td>9.987999</td>
#     </tr>
#     <tr>
#       <th>9994</th>
#       <td>-0.053614</td>
#       <td>9.989999</td>
#     </tr>
#     <tr>
#       <th>9995</th>
#       <td>-0.053772</td>
#       <td>9.991999</td>
#     </tr>
#     <tr>
#       <th>9996</th>
#       <td>-0.053930</td>
#       <td>9.993999</td>
#     </tr>
#     <tr>
#       <th>9997</th>
#       <td>-0.054088</td>
#       <td>9.996000</td>
#     </tr>
#     <tr>
#       <th>9998</th>
#       <td>-0.054245</td>
#       <td>9.998000</td>
#     </tr>
#     <tr>
#       <th>9999</th>
#       <td>-0.054402</td>
#       <td>10.000000</td>
#     </tr>
#   </tbody>
# </table>
# <p>10000 rows × 2 columns</p>
# </div>

# %%
sinc.plot(x="x",y="g(x)")

# %% [markdown]
# ## Conclusions
#
# We conclude from the above tests that the lists and the numpy arrays for both equations produce accurate results that make sense.
